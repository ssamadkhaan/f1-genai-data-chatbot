# %%
import pandas as pd
import google.generativeai as genai
from dotenv import load_dotenv
import os
# Out:
# C:\Users\Samad\AppData\Local\Temp\ipykernel_15384\3855125886.py:2: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
load_dotenv()

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

genai.configure(
    api_key=GEMINI_API_KEY
)

model = genai.GenerativeModel(
    "gemini-2.5-flash"
)

print("Gemini Ready")
# Out:
# Gemini Ready

# %%
drivers = pd.read_csv("../data/drivers.csv")
constructors = pd.read_csv("../data/constructors.csv")
races = pd.read_csv("../data/races.csv")
results = pd.read_csv("../data/results.csv")

print("Data Loaded")
# Out:
# Data Loaded

# %%
def get_driver_info(name):

    data = drivers[
        drivers["surname"]
        .str.contains(name, case=False, na=False)
    ]

    return data.head(5)

# %%
def get_constructor_info(name):

    data = constructors[
        constructors["name"]
        .str.contains(name, case=False, na=False)
    ]

    return data.head(5)

# %%
def get_race_info(name):

    data = races[
        races["name"]
        .str.contains(name, case=False, na=False)
    ]

    return data.head(5)

# %%
question = "Tell me about Hamilton"

driver_data = get_driver_info("Hamilton")

prompt = f"""
Question:

{question}

Driver Data:

{driver_data}

Answer professionally.
"""

# %%
response = model.generate_content(
    prompt
)

print(response.text)
# Out:
# When you ask about 'Hamilton,' it most commonly refers to **Lewis Hamilton**, one of the most successful drivers in Formula 1 history. However, the provided data also includes **Duncan Hamilton**, a notable British racing driver from an earlier era.
#
# Here is a summary of both:
#
# ### Lewis Hamilton (Driver ID: 1)
#
# *   **Full Name:** Sir Lewis Carl Davidson Hamilton
# *   **Nationality:** British
# *   **Date of Birth:** January 7, 1985
# *   **Key Achievements:** Lewis Hamilton is a seven-time Formula 1 World Champion, a record he shares with Michael Schumacher. He holds numerous Formula 1 records, including the most career wins, pole positions, and podium finishes. Considered one of the greatest F1 drivers of all time, he achieved most of his championships with the Mercedes-AMG Petronas F1 Team, after starting his career with McLaren.
#
# ### Duncan Hamilton (Driver ID: 708)
#
# *   **Full Name:** Duncan Hamilton
# *   **Nationality:** British
# ...

# %%
print(
    "Notebook 15 setup complete."
)
# Out:
# Notebook 15 setup complete.

# %% [markdown]
# ## Conclusion
#
# In this notebook, a Streamlit-based F1 GenAI Chatbot was developed and deployed locally. The application provides a simple web interface where users can ask Formula 1 related questions in natural language.
#
# Key achievements:
# - Built a user-friendly Streamlit interface.
# - Connected the chatbot to the Gemini model.
# - Processed F1-related user questions dynamically.
# - Generated AI-powered responses in a web application.
# - Demonstrated how GenAI applications can be deployed for end users.
#
# This notebook completes the F1 GenAI Chatbot project by transforming the backend logic into an interactive web application.
